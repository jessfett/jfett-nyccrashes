# %%
import pandas as pd
import csv
from sqlalchemy import create_engine

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
import numpy as np

# %%
file_one = "ETL/Data/2020Crashes.csv"

# %%
crashes2020 = pd.read_csv(file_one, encoding="ISO-8859-1")

# %%
crashes2020.head()
# Out:
#    CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  01/02/2020      12:57        NaN       NaN        NaN        NaN
# 1  01/02/2020      20:00        NaN       NaN        NaN        NaN
# 2  01/02/2020      22:57        NaN       NaN        NaN        NaN
# 3  01/02/2020      15:14   BROOKLYN   11206.0  40.698376 -73.937710
# 4  01/02/2020       0:00  MANHATTAN   10030.0  40.817886 -73.945526
#
#                   LOCATION                    ON STREET NAME  \
# 0                      NaN  W 57 & 8th Ave
# 1                      NaN  ALAMEDA AVENUE
# 2                      NaN  LIBERTY AVENUE
# 3   (40.698376, -73.93771)                               NaN
# 4  (40.817886, -73.945526)                               NaN
#
#     CROSS STREET NAME                           OFF STREET NAME  ...  \
# 0                W 57                                       NaN  ...
# 1  NORTHERN BOULEVARD                                       NaN  ...
# 2  VANWYCK EXPRESSWAY                                       NaN  ...
# 3                 NaN  871       BROADWAY                        ...
# 4                 NaN  2570      8 AVENUE                        ...
#
#     CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                     Unspecified                            NaN
# 1                     Unspecified                            NaN
# 2  Driver Inattention/Distraction                            NaN
# 3                     Unspecified                            NaN
# 4             Driver Inexperience                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN                            NaN       4268255
# 1                            NaN                            NaN       4268437
# 2                            NaN                            NaN       4270521
# 3                            NaN                            NaN       4354121
# 4                            NaN                            NaN       4267966
#
#                    VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  \
# 0                                 Taxi        Pick-up Truck
# 1                                Sedan                Sedan
# 2  Station Wagon/Sport Utility Vehicle                Sedan
# 3                             suburban                moped
# 4                                Sedan                 Taxi
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
del crashes2020['ON STREET NAME']
del crashes2020['CROSS STREET NAME']
del crashes2020['OFF STREET NAME']
del crashes2020['CONTRIBUTING FACTOR VEHICLE 3']
del crashes2020['CONTRIBUTING FACTOR VEHICLE 4']
del crashes2020['CONTRIBUTING FACTOR VEHICLE 5']
del crashes2020['VEHICLE TYPE CODE 3']
del crashes2020['VEHICLE TYPE CODE 4']
del crashes2020['VEHICLE TYPE CODE 5']

# %%
crashes2020

crashes2020 = crashes2020[crashes2020['BOROUGH'].notna()]

# %%
crashes2020 = crashes2020[crashes2020['LATITUDE'].notna()]

# %%
crashes2020 = crashes2020[crashes2020['LONGITUDE'].notna()]

# %%
crashes2020
# Out:
#         CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 3       01/02/2020      15:14   BROOKLYN   11206.0  40.698376 -73.937710
# 4       01/02/2020       0:00  MANHATTAN   10030.0  40.817886 -73.945526
# 10      01/02/2020      15:00  MANHATTAN   10002.0  40.714085 -73.982506
# 12      01/02/2020      20:06  MANHATTAN   10022.0  40.757637 -73.963420
# 13      01/02/2020      18:00   BROOKLYN   11236.0  40.653896 -73.901420
# ...            ...        ...        ...       ...        ...        ...
# 105910  12/08/2020      17:34   BROOKLYN   11217.0  40.686756 -73.975525
# 105911  12/08/2020       9:53   BROOKLYN   11207.0  40.654080 -73.891620
# 105912  12/08/2020      18:00   BROOKLYN   11214.0  40.583664 -73.986560
# 105914  12/08/2020       9:00  MANHATTAN   10022.0  40.761610 -73.970760
# 105915  12/08/2020       9:34      BRONX   10451.0  40.824970 -73.922280
#
#                        LOCATION  NUMBER OF PERSONS INJURED  \
# 3        (40.698376, -73.93771)                          1
# 4       (40.817886, -73.945526)                          0
# 10      (40.714085, -73.982506)                          0
# 12       (40.757637, -73.96342)                          1
# 13       (40.653896, -73.90142)                          3
# ...                         ...                        ...
# 105910  (40.686756, -73.975525)                          1
# 105911    (40.65408, -73.89162)                          0
# 105912   (40.583664, -73.98656)                          0
# 105914    (40.76161, -73.97076)                          0
# 105915    (40.82497, -73.92228)                          0
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 3                              0                              0
# 4                              0                              0
# 10                             0                              0
# 12                             0                              1
# 13                             0                              0
# ...                          ...                            ...
# 105910                         0                              1
# 105911                         0                              0
# 105912                         0                              0
# 105914                         0                              0
# 105915                         0                              0
#
#         NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# 3                                  0                          0
# 4                                  0                          0
# 10                                 0                          0
# 12                                 0                          0
# 13                                 0                          0
# ...                              ...                        ...
# 105910                             0                          0
# 105911                             0                          0
# 105912                             0                          0
# 105914                             0                          0
# 105915                             0                          0
#
#         NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# 3                              0                           1
# 4                              0                           0
# 10                             0                           0
# 12                             0                           0
# 13                             0                           3
# ...                          ...                         ...
# 105910                         0                           0
# 105911                         0                           0
# 105912                         0                           0
# 105914                         0                           0
# 105915                         0                           0
#
#         NUMBER OF MOTORIST KILLED  \
# 3                               0
# 4                               0
# 10                              0
# 12                              0
# 13                              0
# ...                           ...
# 105910                          0
# 105911                          0
# 105912                          0
# 105914                          0
# 105915                          0
#
#                             CONTRIBUTING FACTOR VEHICLE 1  \
# 3       Pedestrian/Bicyclist/Other Pedestrian Error/Co...
# 4                          Driver Inattention/Distraction
# 10                                            Unspecified
# 12                         Driver Inattention/Distraction
# 13                          Failure to Yield Right-of-Way
# ...                                                   ...
# 105910                     Driver Inattention/Distraction
# 105911                                        Unspecified
# 105912                     Driver Inattention/Distraction
# 105914                      Failure to Yield Right-of-Way
# 105915                                Passing Too Closely
#
#          CONTRIBUTING FACTOR VEHICLE 2  COLLISION_ID  \
# 3                          Unspecified       4354121
# 4                  Driver Inexperience       4267966
# 10                                 NaN       4268280
# 12                                 NaN       4268125
# 13                         Unspecified       4271706
# ...                                ...           ...
# 105910                             NaN       4374330
# 105911                     Unspecified       4374545
# 105912  Driver Inattention/Distraction       4374392
# 105914                     Unspecified       4374197
# 105915               Oversized Vehicle       4374371
#
#                         VEHICLE TYPE CODE 1  \
# 3                                  suburban
# 4                                     Sedan
# 10                                    Sedan
# 12      Station Wagon/Sport Utility Vehicle
# 13      Station Wagon/Sport Utility Vehicle
# ...                                     ...
# 105910  Station Wagon/Sport Utility Vehicle
# 105911                            Box Truck
# 105912  Station Wagon/Sport Utility Vehicle
# 105914                                 Taxi
# 105915                            Box Truck
#
#                         VEHICLE TYPE CODE 2
# 3                                     moped
# 4                                      Taxi
# 10                                      NaN
# 12                                      NaN
# 13                                    Sedan
# ...                                     ...
# 105910                                  NaN
# 105911  Station Wagon/Sport Utility Vehicle
# 105912  Station Wagon/Sport Utility Vehicle
# 105914                                Sedan
# 105915                                Sedan
#
# [67229 rows x 20 columns]

# %%
del crashes2020['CONTRIBUTING FACTOR VEHICLE 2']
del crashes2020['VEHICLE TYPE CODE 2']

# %%
crashes2020_df = crashes2020.rename(columns={"CRASH DATE":"CrashDate", "CRASH TIME": "CrashTime", "ZIP CODE": "ZipCode",
                                            "NUMBER OF PERSONS INJURED": "PersonsInjured", "NUMBER OF PERSONS KILLED": "PersonsKilled",
                                            "NUMBER OF PEDESTRIANS INJURED": "PedestriansInjured", "NUMBER OF PEDESTRIANS KILLED": "PedestriansKilled", 
                                            "NUMBER OF CYCLIST INJURED": "CyclistInjured", "NUMBER OF CYCLIST KILLED": "CyclistKilled",
                                            "NUMBER OF MOTORIST INJURED": "MotoristInjured", "NUMBER OF MOTORIST KILLED": "MotoristKilled",
                                            "CONTRIBUTING FACTOR VEHICLE 1": "ContributingFactor", "VEHICLE TYPE CODE 1": "VehicleType"})

# %%
crashes2020_df
# Out:
#          CrashDate CrashTime    BOROUGH  ZipCode   LATITUDE  LONGITUDE  \
# 3       01/02/2020     15:14   BROOKLYN  11206.0  40.698376 -73.937710
# 4       01/02/2020      0:00  MANHATTAN  10030.0  40.817886 -73.945526
# 10      01/02/2020     15:00  MANHATTAN  10002.0  40.714085 -73.982506
# 12      01/02/2020     20:06  MANHATTAN  10022.0  40.757637 -73.963420
# 13      01/02/2020     18:00   BROOKLYN  11236.0  40.653896 -73.901420
# ...            ...       ...        ...      ...        ...        ...
# 105910  12/08/2020     17:34   BROOKLYN  11217.0  40.686756 -73.975525
# 105911  12/08/2020      9:53   BROOKLYN  11207.0  40.654080 -73.891620
# 105912  12/08/2020     18:00   BROOKLYN  11214.0  40.583664 -73.986560
# 105914  12/08/2020      9:00  MANHATTAN  10022.0  40.761610 -73.970760
# 105915  12/08/2020      9:34      BRONX  10451.0  40.824970 -73.922280
#
#                        LOCATION  PersonsInjured  PersonsKilled  \
# 3        (40.698376, -73.93771)               1              0
# 4       (40.817886, -73.945526)               0              0
# 10      (40.714085, -73.982506)               0              0
# 12       (40.757637, -73.96342)               1              0
# 13       (40.653896, -73.90142)               3              0
# ...                         ...             ...            ...
# 105910  (40.686756, -73.975525)               1              0
# 105911    (40.65408, -73.89162)               0              0
# 105912   (40.583664, -73.98656)               0              0
# 105914    (40.76161, -73.97076)               0              0
# 105915    (40.82497, -73.92228)               0              0
#
#         PedestriansInjured  PedestriansKilled  CyclistInjured  CyclistKilled  \
# 3                        0                  0               0              0
# 4                        0                  0               0              0
# 10                       0                  0               0              0
# 12                       1                  0               0              0
# 13                       0                  0               0              0
# ...                    ...                ...             ...            ...
# 105910                   1                  0               0              0
# 105911                   0                  0               0              0
# 105912                   0                  0               0              0
# 105914                   0                  0               0              0
# 105915                   0                  0               0              0
#
#         MotoristInjured  MotoristKilled  \
# 3                     1               0
# 4                     0               0
# 10                    0               0
# 12                    0               0
# 13                    3               0
# ...                 ...             ...
# 105910                0               0
# 105911                0               0
# 105912                0               0
# 105914                0               0
# 105915                0               0
#
#                                        ContributingFactor  COLLISION_ID  \
# 3       Pedestrian/Bicyclist/Other Pedestrian Error/Co...       4354121
# 4                          Driver Inattention/Distraction       4267966
# 10                                            Unspecified       4268280
# 12                         Driver Inattention/Distraction       4268125
# 13                          Failure to Yield Right-of-Way       4271706
# ...                                                   ...           ...
# 105910                     Driver Inattention/Distraction       4374330
# 105911                                        Unspecified       4374545
# 105912                     Driver Inattention/Distraction       4374392
# 105914                      Failure to Yield Right-of-Way       4374197
# 105915                                Passing Too Closely       4374371
#
#                                 VehicleType
# 3                                  suburban
# 4                                     Sedan
# 10                                    Sedan
# 12      Station Wagon/Sport Utility Vehicle
# 13      Station Wagon/Sport Utility Vehicle
# ...                                     ...
# 105910  Station Wagon/Sport Utility Vehicle
# 105911                            Box Truck
# 105912  Station Wagon/Sport Utility Vehicle
# 105914                                 Taxi
# 105915                            Box Truck
#
# [67229 rows x 18 columns]

# %%
crashes2020_df = crashes2020_df.rename(columns={"BOROUGH":"Borough", "LATITUDE": "Latitude", "LONGITUDE": "Longitude", 
                                                "LOCATION": "Location", "COLLISION_ID": "CollisionID"})

# %%
crashes2020_df
# Out:
#          CrashDate CrashTime    Borough  ZipCode   Latitude  Longitude  \
# 3       01/02/2020     15:14   BROOKLYN  11206.0  40.698376 -73.937710
# 4       01/02/2020      0:00  MANHATTAN  10030.0  40.817886 -73.945526
# 10      01/02/2020     15:00  MANHATTAN  10002.0  40.714085 -73.982506
# 12      01/02/2020     20:06  MANHATTAN  10022.0  40.757637 -73.963420
# 13      01/02/2020     18:00   BROOKLYN  11236.0  40.653896 -73.901420
# ...            ...       ...        ...      ...        ...        ...
# 105910  12/08/2020     17:34   BROOKLYN  11217.0  40.686756 -73.975525
# 105911  12/08/2020      9:53   BROOKLYN  11207.0  40.654080 -73.891620
# 105912  12/08/2020     18:00   BROOKLYN  11214.0  40.583664 -73.986560
# 105914  12/08/2020      9:00  MANHATTAN  10022.0  40.761610 -73.970760
# 105915  12/08/2020      9:34      BRONX  10451.0  40.824970 -73.922280
#
#                        Location  PersonsInjured  PersonsKilled  \
# 3        (40.698376, -73.93771)               1              0
# 4       (40.817886, -73.945526)               0              0
# 10      (40.714085, -73.982506)               0              0
# 12       (40.757637, -73.96342)               1              0
# 13       (40.653896, -73.90142)               3              0
# ...                         ...             ...            ...
# 105910  (40.686756, -73.975525)               1              0
# 105911    (40.65408, -73.89162)               0              0
# 105912   (40.583664, -73.98656)               0              0
# 105914    (40.76161, -73.97076)               0              0
# 105915    (40.82497, -73.92228)               0              0
#
#         PedestriansInjured  PedestriansKilled  CyclistInjured  CyclistKilled  \
# 3                        0                  0               0              0
# 4                        0                  0               0              0
# 10                       0                  0               0              0
# 12                       1                  0               0              0
# 13                       0                  0               0              0
# ...                    ...                ...             ...            ...
# 105910                   1                  0               0              0
# 105911                   0                  0               0              0
# 105912                   0                  0               0              0
# 105914                   0                  0               0              0
# 105915                   0                  0               0              0
#
#         MotoristInjured  MotoristKilled  \
# 3                     1               0
# 4                     0               0
# 10                    0               0
# 12                    0               0
# 13                    3               0
# ...                 ...             ...
# 105910                0               0
# 105911                0               0
# 105912                0               0
# 105914                0               0
# 105915                0               0
#
#                                        ContributingFactor  CollisionID  \
# 3       Pedestrian/Bicyclist/Other Pedestrian Error/Co...      4354121
# 4                          Driver Inattention/Distraction      4267966
# 10                                            Unspecified      4268280
# 12                         Driver Inattention/Distraction      4268125
# 13                          Failure to Yield Right-of-Way      4271706
# ...                                                   ...          ...
# 105910                     Driver Inattention/Distraction      4374330
# 105911                                        Unspecified      4374545
# 105912                     Driver Inattention/Distraction      4374392
# 105914                      Failure to Yield Right-of-Way      4374197
# 105915                                Passing Too Closely      4374371
#
#                                 VehicleType
# 3                                  suburban
# 4                                     Sedan
# 10                                    Sedan
# 12      Station Wagon/Sport Utility Vehicle
# 13      Station Wagon/Sport Utility Vehicle
# ...                                     ...
# 105910  Station Wagon/Sport Utility Vehicle
# 105911                            Box Truck
# 105912  Station Wagon/Sport Utility Vehicle
# 105914                                 Taxi
# 105915                            Box Truck
#
# [67229 rows x 18 columns]

# %%
del crashes2020_df['Location']

# %%
crashes2020_df["CrashDate"] = pd.to_datetime(crashes2020_df["CrashDate"]).dt.strftime('%Y-%m-%d')
print(crashes2020_df)
# Out:
#          CrashDate CrashTime    Borough  ZipCode   Latitude  Longitude  \
# 3       2020-01-02     15:14   BROOKLYN  11206.0  40.698376 -73.937710
# 4       2020-01-02      0:00  MANHATTAN  10030.0  40.817886 -73.945526
# 10      2020-01-02     15:00  MANHATTAN  10002.0  40.714085 -73.982506
# 12      2020-01-02     20:06  MANHATTAN  10022.0  40.757637 -73.963420
# 13      2020-01-02     18:00   BROOKLYN  11236.0  40.653896 -73.901420
# ...            ...       ...        ...      ...        ...        ...
# 105910  2020-12-08     17:34   BROOKLYN  11217.0  40.686756 -73.975525
# 105911  2020-12-08      9:53   BROOKLYN  11207.0  40.654080 -73.891620
# 105912  2020-12-08     18:00   BROOKLYN  11214.0  40.583664 -73.986560
# 105914  2020-12-08      9:00  MANHATTAN  10022.0  40.761610 -73.970760
# 105915  2020-12-08      9:34      BRONX  10451.0  40.824970 -73.922280
#
#         PersonsInjured  PersonsKilled  PedestriansInjured  PedestriansKilled  \
# 3                    1              0                   0                  0
# 4                    0              0                   0                  0
# 10                   0              0                   0                  0
# 12                   1              0                   1                  0
# 13                   3              0                   0                  0
# ...                ...            ...                 ...                ...
# 105910               1              0                   1                  0
# 105911               0              0                   0                  0
# 105912               0              0                   0                  0
# 105914               0              0                   0                  0
# 105915               0              0                   0                  0
#
#         CyclistInjured  CyclistKilled  MotoristInjured  MotoristKilled  \
# 3                    0              0                1               0
# 4                    0              0                0               0
# 10                   0              0                0               0
# 12                   0              0                0               0
# 13                   0              0                3               0
# ...                ...            ...              ...             ...
# 105910               0              0                0               0
# 105911               0              0                0               0
# 105912               0              0                0               0
# 105914               0              0                0               0
# 105915               0              0                0               0
#
#                                        ContributingFactor  CollisionID  \
# 3       Pedestrian/Bicyclist/Other Pedestrian Error/Co...      4354121
# 4                          Driver Inattention/Distraction      4267966
# 10                                            Unspecified      4268280
# 12                         Driver Inattention/Distraction      4268125
# 13                          Failure to Yield Right-of-Way      4271706
# ...                                                   ...          ...
# 105910                     Driver Inattention/Distraction      4374330
# 105911                                        Unspecified      4374545
# 105912                     Driver Inattention/Distraction      4374392
# 105914                      Failure to Yield Right-of-Way      4374197
# 105915                                Passing Too Closely      4374371
#
#                                 VehicleType
# 3                                  suburban
# 4                                     Sedan
# 10                                    Sedan
# 12      Station Wagon/Sport Utility Vehicle
# 13      Station Wagon/Sport Utility Vehicle
# ...                                     ...
# 105910  Station Wagon/Sport Utility Vehicle
# 105911                            Box Truck
# 105912  Station Wagon/Sport Utility Vehicle
# 105914                                 Taxi
# 105915                            Box Truck
#
# [67229 rows x 17 columns]

# %%
crashes2020_df.head()
# Out:
#      CrashDate CrashTime    Borough  ZipCode   Latitude  Longitude  \
# 3   2020-01-02     15:14   BROOKLYN  11206.0  40.698376 -73.937710
# 4   2020-01-02      0:00  MANHATTAN  10030.0  40.817886 -73.945526
# 10  2020-01-02     15:00  MANHATTAN  10002.0  40.714085 -73.982506
# 12  2020-01-02     20:06  MANHATTAN  10022.0  40.757637 -73.963420
# 13  2020-01-02     18:00   BROOKLYN  11236.0  40.653896 -73.901420
#
#     PersonsInjured  PersonsKilled  PedestriansInjured  PedestriansKilled  \
# 3                1              0                   0                  0
# 4                0              0                   0                  0
# 10               0              0                   0                  0
# 12               1              0                   1                  0
# 13               3              0                   0                  0
#
#     CyclistInjured  CyclistKilled  MotoristInjured  MotoristKilled  \
# 3                0              0                1               0
# 4                0              0                0               0
# 10               0              0                0               0
# 12               0              0                0               0
# 13               0              0                3               0
#
#                                    ContributingFactor  CollisionID  \
# 3   Pedestrian/Bicyclist/Other Pedestrian Error/Co...      4354121
# 4                      Driver Inattention/Distraction      4267966
# 10                                        Unspecified      4268280
# 12                     Driver Inattention/Distraction      4268125
# 13                      Failure to Yield Right-of-Way      4271706
#
#                             VehicleType
# 3                              suburban
# 4                                 Sedan
# 10                                Sedan
# 12  Station Wagon/Sport Utility Vehicle
# 13  Station Wagon/Sport Utility Vehicle

# %%
del crashes2020_df['ZipCode']

# %%
crashes2020_df
# Out:
#          CrashDate CrashTime    Borough   Latitude  Longitude  PersonsInjured  \
# 3       2020-01-02     15:14   BROOKLYN  40.698376 -73.937710               1
# 4       2020-01-02      0:00  MANHATTAN  40.817886 -73.945526               0
# 10      2020-01-02     15:00  MANHATTAN  40.714085 -73.982506               0
# 12      2020-01-02     20:06  MANHATTAN  40.757637 -73.963420               1
# 13      2020-01-02     18:00   BROOKLYN  40.653896 -73.901420               3
# ...            ...       ...        ...        ...        ...             ...
# 105910  2020-12-08     17:34   BROOKLYN  40.686756 -73.975525               1
# 105911  2020-12-08      9:53   BROOKLYN  40.654080 -73.891620               0
# 105912  2020-12-08     18:00   BROOKLYN  40.583664 -73.986560               0
# 105914  2020-12-08      9:00  MANHATTAN  40.761610 -73.970760               0
# 105915  2020-12-08      9:34      BRONX  40.824970 -73.922280               0
#
#         PersonsKilled  PedestriansInjured  PedestriansKilled  CyclistInjured  \
# 3                   0                   0                  0               0
# 4                   0                   0                  0               0
# 10                  0                   0                  0               0
# 12                  0                   1                  0               0
# 13                  0                   0                  0               0
# ...               ...                 ...                ...             ...
# 105910              0                   1                  0               0
# 105911              0                   0                  0               0
# 105912              0                   0                  0               0
# 105914              0                   0                  0               0
# 105915              0                   0                  0               0
#
#         CyclistKilled  MotoristInjured  MotoristKilled  \
# 3                   0                1               0
# 4                   0                0               0
# 10                  0                0               0
# 12                  0                0               0
# 13                  0                3               0
# ...               ...              ...             ...
# 105910              0                0               0
# 105911              0                0               0
# 105912              0                0               0
# 105914              0                0               0
# 105915              0                0               0
#
#                                        ContributingFactor  CollisionID  \
# 3       Pedestrian/Bicyclist/Other Pedestrian Error/Co...      4354121
# 4                          Driver Inattention/Distraction      4267966
# 10                                            Unspecified      4268280
# 12                         Driver Inattention/Distraction      4268125
# 13                          Failure to Yield Right-of-Way      4271706
# ...                                                   ...          ...
# 105910                     Driver Inattention/Distraction      4374330
# 105911                                        Unspecified      4374545
# 105912                     Driver Inattention/Distraction      4374392
# 105914                      Failure to Yield Right-of-Way      4374197
# 105915                                Passing Too Closely      4374371
#
#                                 VehicleType
# 3                                  suburban
# 4                                     Sedan
# 10                                    Sedan
# 12      Station Wagon/Sport Utility Vehicle
# 13      Station Wagon/Sport Utility Vehicle
# ...                                     ...
# 105910  Station Wagon/Sport Utility Vehicle
# 105911                            Box Truck
# 105912  Station Wagon/Sport Utility Vehicle
# 105914                                 Taxi
# 105915                            Box Truck
#
# [67229 rows x 16 columns]

# %%
crashes2020_df=crashes2020_df.round({'Latitude': 4, 'Longitude': 4})

# %%
crashes2020_df
# Out:
#          CrashDate CrashTime    Borough  Latitude  Longitude  PersonsInjured  \
# 3       2020-01-02     15:14   BROOKLYN   40.6984   -73.9377               1
# 4       2020-01-02      0:00  MANHATTAN   40.8179   -73.9455               0
# 10      2020-01-02     15:00  MANHATTAN   40.7141   -73.9825               0
# 12      2020-01-02     20:06  MANHATTAN   40.7576   -73.9634               1
# 13      2020-01-02     18:00   BROOKLYN   40.6539   -73.9014               3
# ...            ...       ...        ...       ...        ...             ...
# 105910  2020-12-08     17:34   BROOKLYN   40.6868   -73.9755               1
# 105911  2020-12-08      9:53   BROOKLYN   40.6541   -73.8916               0
# 105912  2020-12-08     18:00   BROOKLYN   40.5837   -73.9866               0
# 105914  2020-12-08      9:00  MANHATTAN   40.7616   -73.9708               0
# 105915  2020-12-08      9:34      BRONX   40.8250   -73.9223               0
#
#         PersonsKilled  PedestriansInjured  PedestriansKilled  CyclistInjured  \
# 3                   0                   0                  0               0
# 4                   0                   0                  0               0
# 10                  0                   0                  0               0
# 12                  0                   1                  0               0
# 13                  0                   0                  0               0
# ...               ...                 ...                ...             ...
# 105910              0                   1                  0               0
# 105911              0                   0                  0               0
# 105912              0                   0                  0               0
# 105914              0                   0                  0               0
# 105915              0                   0                  0               0
#
#         CyclistKilled  MotoristInjured  MotoristKilled  \
# 3                   0                1               0
# 4                   0                0               0
# 10                  0                0               0
# 12                  0                0               0
# 13                  0                3               0
# ...               ...              ...             ...
# 105910              0                0               0
# 105911              0                0               0
# 105912              0                0               0
# 105914              0                0               0
# 105915              0                0               0
#
#                                        ContributingFactor  CollisionID  \
# 3       Pedestrian/Bicyclist/Other Pedestrian Error/Co...      4354121
# 4                          Driver Inattention/Distraction      4267966
# 10                                            Unspecified      4268280
# 12                         Driver Inattention/Distraction      4268125
# 13                          Failure to Yield Right-of-Way      4271706
# ...                                                   ...          ...
# 105910                     Driver Inattention/Distraction      4374330
# 105911                                        Unspecified      4374545
# 105912                     Driver Inattention/Distraction      4374392
# 105914                      Failure to Yield Right-of-Way      4374197
# 105915                                Passing Too Closely      4374371
#
#                                 VehicleType
# 3                                  suburban
# 4                                     Sedan
# 10                                    Sedan
# 12      Station Wagon/Sport Utility Vehicle
# 13      Station Wagon/Sport Utility Vehicle
# ...                                     ...
# 105910  Station Wagon/Sport Utility Vehicle
# 105911                            Box Truck
# 105912  Station Wagon/Sport Utility Vehicle
# 105914                                 Taxi
# 105915                            Box Truck
#
# [67229 rows x 16 columns]

# %%
crashes2020_df.to_csv("ETL/Data/NYC2020crashes.csv", index=False, header=True)

# %%
html_table = crashes2020_df.to_html()

# %%
crashes2020_df.to_html('Web/table.html')

# %%
crashes2020_df.to_json(r'Path to store the exported JSON file\File Name.json')

# %% [markdown]
# # Borough Totals

# %%
crashes2020_df
# Out:
#          CrashDate CrashTime    Borough  Latitude  Longitude  PersonsInjured  \
# 3       2020-01-02     15:14   BROOKLYN   40.6984   -73.9377               1
# 4       2020-01-02      0:00  MANHATTAN   40.8179   -73.9455               0
# 10      2020-01-02     15:00  MANHATTAN   40.7141   -73.9825               0
# 12      2020-01-02     20:06  MANHATTAN   40.7576   -73.9634               1
# 13      2020-01-02     18:00   BROOKLYN   40.6539   -73.9014               3
# ...            ...       ...        ...       ...        ...             ...
# 105910  2020-12-08     17:34   BROOKLYN   40.6868   -73.9755               1
# 105911  2020-12-08      9:53   BROOKLYN   40.6541   -73.8916               0
# 105912  2020-12-08     18:00   BROOKLYN   40.5837   -73.9866               0
# 105914  2020-12-08      9:00  MANHATTAN   40.7616   -73.9708               0
# 105915  2020-12-08      9:34      BRONX   40.8250   -73.9223               0
#
#         PersonsKilled  PedestriansInjured  PedestriansKilled  CyclistInjured  \
# 3                   0                   0                  0               0
# 4                   0                   0                  0               0
# 10                  0                   0                  0               0
# 12                  0                   1                  0               0
# 13                  0                   0                  0               0
# ...               ...                 ...                ...             ...
# 105910              0                   1                  0               0
# 105911              0                   0                  0               0
# 105912              0                   0                  0               0
# 105914              0                   0                  0               0
# 105915              0                   0                  0               0
#
#         CyclistKilled  MotoristInjured  MotoristKilled  \
# 3                   0                1               0
# 4                   0                0               0
# 10                  0                0               0
# 12                  0                0               0
# 13                  0                3               0
# ...               ...              ...             ...
# 105910              0                0               0
# 105911              0                0               0
# 105912              0                0               0
# 105914              0                0               0
# 105915              0                0               0
#
#                                        ContributingFactor  CollisionID  \
# 3       Pedestrian/Bicyclist/Other Pedestrian Error/Co...      4354121
# 4                          Driver Inattention/Distraction      4267966
# 10                                            Unspecified      4268280
# 12                         Driver Inattention/Distraction      4268125
# 13                          Failure to Yield Right-of-Way      4271706
# ...                                                   ...          ...
# 105910                     Driver Inattention/Distraction      4374330
# 105911                                        Unspecified      4374545
# 105912                     Driver Inattention/Distraction      4374392
# 105914                      Failure to Yield Right-of-Way      4374197
# 105915                                Passing Too Closely      4374371
#
#                                 VehicleType
# 3                                  suburban
# 4                                     Sedan
# 10                                    Sedan
# 12      Station Wagon/Sport Utility Vehicle
# 13      Station Wagon/Sport Utility Vehicle
# ...                                     ...
# 105910  Station Wagon/Sport Utility Vehicle
# 105911                            Box Truck
# 105912  Station Wagon/Sport Utility Vehicle
# 105914                                 Taxi
# 105915                            Box Truck
#
# [67229 rows x 16 columns]

# %%
crash_count = crashes2020_df.groupby(['Borough']).count()
crash_count
# Out:
#                CrashDate  CrashTime  Latitude  Longitude  PersonsInjured  \
# Borough
# BRONX              12937      12937     12937      12937           12937
# BROOKLYN           23395      23395     23395      23395           23395
# MANHATTAN           9915       9915      9915       9915            9915
# QUEENS             18881      18881     18881      18881           18881
# STATEN ISLAND       2101       2101      2101       2101            2101
#
#                PersonsKilled  PedestriansInjured  PedestriansKilled  \
# Borough
# BRONX                  12937               12937              12937
# BROOKLYN               23395               23395              23395
# MANHATTAN               9915                9915               9915
# QUEENS                 18881               18881              18881
# STATEN ISLAND           2101                2101               2101
#
#                CyclistInjured  CyclistKilled  MotoristInjured  MotoristKilled  \
# Borough
# BRONX                   12937          12937            12937           12937
# BROOKLYN                23395          23395            23395           23395
# MANHATTAN                9915           9915             9915            9915
# QUEENS                  18881          18881            18881           18881
# STATEN ISLAND            2101           2101             2101            2101
#
#                ContributingFactor  CollisionID  VehicleType
# Borough
# BRONX                       12847        12937        12751
# BROOKLYN                    23281        23395        23159
# MANHATTAN                    9861         9915         9808
# QUEENS                      18802        18881        18695
# STATEN ISLAND                2094         2101         2080

# %%
crash_count = crash_count.rename(columns={"CrashDate": "CrashCount"})

# %%
del crash_count['CrashTime']
del crash_count['Latitude']
del crash_count['Longitude']
del crash_count['PersonsInjured']
del crash_count['PersonsKilled']
del crash_count['PedestriansInjured']
del crash_count['PedestriansKilled']
del crash_count['CyclistInjured']
del crash_count['CyclistKilled']
del crash_count['MotoristInjured']
del crash_count['MotoristKilled']
del crash_count['ContributingFactor']
del crash_count['CollisionID']
del crash_count['VehicleType']

# %%
crashcount = crash_count.reset_index()

# %%
crashcount.to_csv("Data/CrashCount.csv", index=False, header=True)

# %%
crash_impact = crashes2020_df.groupby(['Borough']).sum()
crash_impact
# Out:
#                   Latitude     Longitude  PersonsInjured  PersonsKilled  \
# Borough
# BRONX          527379.5635 -9.539012e+05            4688             19
# BROOKLYN       949544.0617 -1.727092e+06            8915             37
# MANHATTAN      403545.5562 -7.321553e+05            3256             18
# QUEENS         767398.7535 -1.391554e+06            6635             44
# STATEN ISLAND   84841.1402 -1.549078e+05             834              8
#
#                PedestriansInjured  PedestriansKilled  CyclistInjured  \
# Borough
# BRONX                         896                  7             581
# BROOKLYN                     1631                 15            1456
# MANHATTAN                     784                  8             886
# QUEENS                       1183                 19             795
# STATEN ISLAND                 105                  3              44
#
#                CyclistKilled  MotoristInjured  MotoristKilled   CollisionID
# Borough
# BRONX                      4             3211               8   55926123546
# BROOKLYN                   6             5828              16  101115965118
# MANHATTAN                  3             1586               7   42827361307
# QUEENS                     1             4657              24   81565362725
# STATEN ISLAND              0              685               5    9087802546

# %%
#del crash_impact['Latitude']
#del crash_impact['Longitude']
del crash_impact['CollisionID']

# %%
crashimpact = crash_impact.reset_index()

# %%
crashimpact.to_csv("Data/CrashImpacts.csv", index=False, header=True)
